# %% [markdown]
# ## DATA ANALYSIS & VISUALIZATION

# %%
import pandas as pd

# %% [markdown]
# The dataset was cleaned and prepared before analysis to ensure accurate results.

# %%
orders=pd.read_csv("orders_cleaned.csv")
order_items=pd.read_csv("order_items_cleaned.csv")
payment=pd.read_csv("order_payment_cleaned.csv")
sellers=pd.read_csv("sellers_cleaned.csv")
products=pd.read_csv("products_cleaned.csv")
review=pd.read_csv("order_review_cleaned.csv")
category=pd.read_csv("category_name_cleaned.csv")
geolocation=pd.read_csv("geolocation_cleaned.csv")
customers=pd.read_csv("customers_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 orders=pd.read_csv("orders_cleaned.csv")
#       2 order_items=pd.read_csv("order_items_cleaned.csv")
#       3 payment=pd.read_csv("order_payment_cleaned.csv")
#       4 sellers=pd.read_csv("sellers_cleaned.csv")
#
# File c:\Users\Teju\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Teju\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Teju\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Teju\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Teju\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'orders_cleaned.csv'

# %% [markdown]
# Monthly revenue shows the total sales in each month.

# %%
orders["order_purchase_timestamp"] = pd.to_datetime(orders["order_purchase_timestamp"])
orders["month"] = orders["order_purchase_timestamp"].dt.month
orders_items_merged = pd.merge(orders, order_items, on="order_id", how="inner")
monthly_revenue = orders_items_merged.groupby("month")["price"].sum()
print(monthly_revenue)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 orders["order_purchase_timestamp"] = pd.to_datetime(orders["order_purchase_timestamp"])
#       2 orders["month"] = orders["order_purchase_timestamp"].dt.month
#       3 orders_items_merged = pd.merge(orders, order_items, on="order_id", how="inner")
#       4 monthly_revenue = orders_items_merged.groupby("month")["price"].sum()
#
# NameError: name 'orders' is not defined

# %% [markdown]
# graph which shows the monthly revenue

# %%
import matplotlib.pyplot as plt
monthly_revenue.plot()
plt.title("monthly Revenue")
plt.xlabel("months")
plt.ylabel("revenue")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# This shows the top 5 most sold products.

# %%
print(order_items["product_id"].value_counts().head(5))
# Out:
# product_id
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
# Name: count, dtype: int64

# %% [markdown]
# Top 5 states which produce heighest revenue.

# %%
order_merged = pd.merge(order_items, orders, on="order_id", how="left")
final_merge = pd.merge(order_merged, customers, on="customer_id", how='left')
final_merge["revenue"] = final_merge["price"] + final_merge["freight_value"]
top_states = final_merge.groupby("customer_state")["revenue"].sum().sort_values(ascending=False).head(5)
print(f"The top 5 states which produce heighest revenue are:\n{top_states}")
# Out:
# The top 5 states which produce heighest revenue are:
# customer_state
# SP    5767792.05
# RJ    2055589.53
# MG    1818644.05
# RS     860724.74
# PR     781708.80
# Name: revenue, dtype: float64

# %% [markdown]
# This shows how many orders are delivered, shipped, and cancelled.

# %%
status=(orders["order_status"].value_counts())
print(status)
# Out:
# order_status
# delivered    96455
# canceled         6
# Name: count, dtype: int64

# %% [markdown]
# Graph which shows the order status.

# %%
import matplotlib.pyplot as plt
status.plot(kind="bar")
plt.title("Order Status Distribution")
plt.xlabel("status")
plt.ylabel("count")
plt.show()

# %% [markdown]
# This shows which payment method is used the most by customers.

# %%
payment=(payment["payment_type"].value_counts())
print(payment)
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %% [markdown]
# graph which shows the payment distribution type

# %%
payment.plot(kind='bar')
plt.title("Payment Type Distribution")
plt.xlabel("Payment Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# This shows the average amount spent per order.

# %%
merged = pd.merge(order_items, orders, on="order_id", how="left")
revenue = merged["price"] + merged["freight_value"]
average_revenue = revenue.mean()
print(f"The average revenue of all the orders is:\n {average_revenue}")
# Out:
# The average revenue of all the orders is:
#  140.6440589436307

# %% [markdown]
# The order purchase time was converted into date format for better analysis.

# %%
orders["order_purchase_timestamp"] = pd.to_datetime(orders["order_purchase_timestamp"])

# %% [markdown]
# These are the top 5 customers who ordered the most.

# %%
merged=pd.merge(orders,customers,on="customer_id",how="left")
group=merged.groupby("customer_id")["order_id"].count().sort_values(ascending=False).head(5)
print(f"The top 5 customers by order are : \n{group}")
# Out:
# The top 5 customers by order are :
# customer_id
# 00012a2ce6f8dcda20d059ce98491703    1
# 000161a058600d5901f007fab4c27140    1
# 0001fd6190edaaf884bcaf3d49edf079    1
# 0002414f95344307404f0ace7a26f1d5    1
# 000379cdec625522490c315e70c7a9fb    1
# Name: order_id, dtype: int64

# %% [markdown]
# This shows the month with the highest revenue.

# %%
heighest_revenue=(monthly_revenue.idxmax())
print(f"The heighest revenue month is = {heighest_revenue} , and it is due to high discount")
print(monthly_revenue.max())
# Out:
# The heighest revenue month is = 5 , and it is due to high discount
# 1466703.94

# %% [markdown]
# This displays the first few rows of the data.

# %%
print(products.head())
print(order_items.head())
print(payment.head())
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %% [markdown]
# This shows the top 5 customers who generated the highest revenue.

# %%
merged=pd.merge(order_items,orders,on="order_id",how="left")
final=pd.merge(merged,customers,on="customer_id",how="left")
final["revenue"]=final["price"]+final["freight_value"]
top_customers=final.groupby(["customer_unique_id","customer_city","customer_state"])["revenue"].sum()
top_customers=top_customers.sort_values(ascending=False).head()
print(f"The top 5 customers who make more revenue are:\n{top_customers}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 merged=pd.merge(order_items,orders,on="order_id",how="left")
#       2 final=pd.merge(merged,customers,on="customer_id",how="left")
#       3 final["revenue"]=final["price"]+final["freight_value"]
#       4 top_customers=final.groupby(["customer_unique_id","customer_city","customer_state"])["revenue"].sum()
#
# NameError: name 'order_items' is not defined

# %% [markdown]
# graph which shows the top 5 customers who generate the highest revenue

# %%
import matplotlib.pyplot as plt
top_customers.plot(kind="bar")
plt.title("top 5 customers who generate highest revenue")
plt.xlabel("customers")
plt.ylabel("revenue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 top_customers.plot(kind="bar")
#       3 plt.title("top 5 customers who generate highest revenue")
#       4 plt.xlabel("customers")
#       5 plt.ylabel("revenue")
#
# NameError: name 'top_customers' is not defined

# %% [markdown]
# This shows the average time taken to deliver the orders.

# %%
orders["order_purchase_timestamp"]=pd.to_datetime(orders["order_purchase_timestamp"])
orders.columns
orders["order_delivered_carrier_date"]=pd.to_datetime(orders["order_delivered_carrier_date"])
time=orders["order_delivered_carrier_date"]-orders["order_purchase_timestamp"]
print(time.mean())
# Out:
# 3 days 05:27:37.866578

# %% [markdown]
# Tables were merged to get complete data and calculate revenue.

# %%
merged=pd.merge(order_items,orders,on="order_id",how="left")
merged1=pd.merge(merged,customers,on="customer_id",how="left")
revenue=merged1["price"]+merged1["freight_value"]

# %% [markdown]
# This shows the top 5 most sold product categories.

# %%
merged=pd.merge(order_items,products,on="product_id",how="left")
top_categories=merged["product_category_name"].value_counts().head()
print(f"The top 5 most selling categories are :\n{top_categories}")
# Out:
# The top 5 most selling categories are :
# product_category_name
# cama_mesa_banho           11115
# beleza_saude               9670
# esporte_lazer              8641
# moveis_decoracao           8334
# informatica_acessorios     7827
# Name: count, dtype: int64

# %% [markdown]
# Graph which shows the top selling categories.

# %%
import matplotlib.pyplot as plt
top_categories.plot(kind="bar")
plt.title("Top Categories sale")
plt.xlabel("top categories")
plt.ylabel("count")
plt.show()

# %%
len(orders)
# Out:
# 96461

# %% [markdown]
# This shows the total amount earned from all products.

# %%
order_items["price"].sum()
# Out:
# np.float64(13591643.7)

# %% [markdown]
# This shows the total number of unique orders.

# %%
unique_orders=orders["order_id"].nunique()
print(unique_orders)
# Out:
# 96461

# %% [markdown]
# This displays the first few rows of the order items table.

# %%
print(order_items.head())
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# This shows the total revenue including product price and delivery charges.

# %%
total_revenue=(order_items["price"]+order_items["freight_value"]).sum()
print(total_revenue)
# Out:
# 15843553.24

# %% [markdown]
# This shows how many items(products) are present in the dataset.

# %%
len(order_items)
# Out:
# 112650
