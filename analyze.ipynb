# %%
import pandas as pd

# %%
print(df.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(df.shape[0])
#
# NameError: name 'df' is not defined

# %%
(df["order_status"]=="delivered").sum()
# Out:
# np.int64(96478)

# %%
(df["order_status"]=="cancelled").sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df["order_purchase_timestamp"]=pd.to_datetime(df["order_purchase_timestamp"])
df["month"]=df["order_purchase_timestamp"].dt.month
monthly_orders=df["month"].value_counts().sort_index()
print(monthly_orders)
print(monthly_orders.idxmax())
# Out:
# month
# 1      8069
# 2      8508
# 3      9893
# 4      9343
# 5     10573
# 6      9412
# 7     10318
# 8     10843
# 9      4305
# 10     4959
# 11     7544
# 12     5674
# Name: count, dtype: int64
# 8

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='str')

# %%
order_item=pd.read_csv("olist_order_items_dataset.csv")

# %%
order_item.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='str')

# %%
len(df)
# Out:
# 99441

# %%
len(order_item)
# Out:
# 112650

# %%
order_item["order_id"].unique()
# Out:
# <StringArray>
# ['00010242fe8c5a6d1ba2dd792cb16214', '00018f77f2f0320c557190d7a144bdd3',
#  '000229ec398224ef6ca0657da4fc703e', '00024acbcdf0a6daa1e931b038114c75',
#  '00042b26cf59d7ce69dfabb4e55b4fd9', '00048cc3ae777c65dbb7d2a0634bc1ea',
#  '00054e8431b9d7675808bcb819fb4a32', '000576fe39319847cbb9d288c5617fa6',
#  '0005a1a1728c9d785b8e2b08b904576c', '0005f50442cb953dcd1d21e1fb923495',
#  ...
#  'fffa82886406ccf10c7b4e35c4ff2788', 'fffb0b1a50e65c449020434fa835e078',
#  'fffb2ef8874127f75b52b643880fd7e0', 'fffb9224b6fc7c43ebb0904318b10b5f',
#  'fffbee3b5462987e66fb49b1c5411df2', 'fffc94f6ce00a00581880bf54a75a037',
#  'fffcd46ef2263f404302a634eb57f7eb', 'fffce4705a9662cd70adb13d4a31832d',
#  'fffe18544ffabc95dfada21779c9644f', 'fffe41c64501cc87c801fd61db3f6244']
# Length: 98666, dtype: str

# %%
revenue=order_item["price"].sum()+order_item["freight_value"].sum()
order=df["order_id"].nunique()
average=revenue/order
print(average)
# Out:
# 159.32616566607334

# %%
revenue=order_item.groupby("order_id")[["price",'freight_value']].sum()
revenue["total"]=revenue["price"]+revenue["freight_value"]
max_order=revenue["total"].idxmax()
print(max_order)
# Out:
# 03caa2c082116e1d31e67e9ae3700499

# %%
revenue.loc["03caa2c082116e1d31e67e9ae3700499"]
# Out:
# price            13440.00
# freight_value      224.08
# total            13664.08
# Name: 03caa2c082116e1d31e67e9ae3700499, dtype: float64

# %%
df["order_status"].unique()
# Out:
# <StringArray>
# [  'delivered',    'invoiced',     'shipped',  'processing', 'unavailable',
#     'canceled',     'created',    'approved']
# Length: 8, dtype: str

# %%
(df["order_status"] == "canceled").sum()
# Out:
# np.int64(625)

# %%
df = pd.read_csv("olist_orders_dataset.csv")

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB

# %%
df["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
merged=pd.merge(df,order_item, on ="order_id")

# %%
merged.head()
merged.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value'],
#       dtype='str')

# %%
revenue=merged["price"].sum()+merged["freight_value"].sum()
print(revenue)
# Out:
# 15843553.240000002

# %%
group=merged.groupby('order_id')[["price","freight_value"]].sum()
print(group)
# Out:
#                                    price  freight_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214   58.90          13.29
# 00018f77f2f0320c557190d7a144bdd3  239.90          19.93
# 000229ec398224ef6ca0657da4fc703e  199.00          17.87
# 00024acbcdf0a6daa1e931b038114c75   12.99          12.79
# 00042b26cf59d7ce69dfabb4e55b4fd9  199.90          18.14
# ...                                  ...            ...
# fffc94f6ce00a00581880bf54a75a037  299.99          43.41
# fffcd46ef2263f404302a634eb57f7eb  350.00          36.53
# fffce4705a9662cd70adb13d4a31832d   99.90          16.95
# fffe18544ffabc95dfada21779c9644f   55.99           8.72
# fffe41c64501cc87c801fd61db3f6244   43.00          12.79
#
# [98666 rows x 2 columns]
